# %% [markdown]
# # SQL Alchemy: Part 1
#
# | Key              | Value                                                                                                                                                                                                                                                                                                                                                          |
# |:-----------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Course Codes** | DAT 2201, DAT 3103, BBT 3104, MCS 8104, MIT 8107, BBT 4106                                                                                                                                                                                                                                                                                                     |
# | **Course Names** | DAT 2201: Database Design and SQL (Week 1-3 of 13), <br/>DAT 3103: Principles of Data Engineering (Week 1-3 of 13), <br/>BBT 3104: Advanced Database Systems (Week 7-9 of 13), <br/>MCS 8104: Database Management Systems (Week 1-3 of 13), <br/>MIT 8107: Advanced Database Systems (Week 1-3 of 13), <br/>BBT 4106: Business Intelligence I (Week 4-6 of 13) |
# | **Semester**     | May to July 2026                                                                                                                                                                                                                                                                                                                                               |
# | **Lecturer**     | Allan Omondi                                                                                                                                                                                                                                                                                                                                                   |
# | **Contact**      | aomondi@strathmore.edu                                                                                                                                                                                                                                                                                                                                         |
# | **Note**         | The lecture contains both theory and practice.<br/>This notebook forms part of the practice.<br/>It is intended for educational purpose only.<br/>Recommended citation: [BibTex](https://raw.githubusercontent.com/course-files/ObjectRelationalMapping/refs/heads/main/RecommendedCitation.bib)                                                               |

# %% [markdown]
# ## Overall Architecture
#
# - The overall architecture is as follows:
#
# **Frontend → Reverse Proxy → API (e.g., Flask or FastAPI) → Backend (e.g., a server running Python) → SQLAlchemy Core (Reads) and SQLAlchemy ORM (Writes) → Database**
#
# - According to the [SQLAlchemy documentation (2025)](https://docs.sqlalchemy.org):
#   - **SQLAlchemy Core** is the foundational architecture for SQLAlchemy as a “database toolkit.” The library provides tools for managing connectivity to a database, interacting with database queries and results, and programmatic construction of SQL statements.
#   - **SQLAlchemy ORM** builds upon SQLAlchemy Core to provide optional Object Relational Mapping (ORM) capabilities. This includes an additional configuration layer allowing user-defined Python classes to be mapped to database tables and other constructs, as well as an object persistence mechanism known as the Session. It then extends the Core-level SQL Expression Language to allow SQL queries to be composed and invoked in terms of user-defined objects.

# %% [markdown]
# ## Install SQLAlchemy
#
# - We need to install SQLAlchemy to work with databases in Python.

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\aomondi\documents\github\teaching\objectrelationalmapping\.venv\lib\site-packages (2.0.44)
# Requirement already satisfied: greenlet>=1 in c:\users\aomondi\documents\github\teaching\objectrelationalmapping\.venv\lib\site-packages (from sqlalchemy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\aomondi\documents\github\teaching\objectrelationalmapping\.venv\lib\site-packages (from sqlalchemy) (4.15.0)

# %% [markdown]
# ## Import SQLAlchemy
#
# - We then import the SQLAlchemy library into the Python environment.

# %%
import sqlalchemy

# %% [markdown]
# The library contains several packages. An alternative way of importing the library is to import specific packages as needed:

# %%
from sqlalchemy import exc

# %% [markdown]
# Another alternative is to import all packages from SQLAlchemy:

# %%
from sqlalchemy import *

# %% [markdown]
# ## Check the Version of SQLAlchemy
#
# - We can confirm the version of SQLAlchemy installed using the `__version__` attribute. This notebook is based on version `2.0.44` of SQLAlchemy.

# %%
sqlalchemy.__version__
# Out:
# '2.0.44'

# %% [markdown]
# ## Create an Engine to Connect to the Database
#
# - `create_engine()` is a function in SQLAlchemy that creates a new SQLAlchemy Engine instance. An Engine is the starting point for any SQLAlchemy application that wants to interact with a database. It manages the connection pool and provides a source of database connections.
# - `echo=True` instructs SQLAlchemy to log all the SQL statements it executes to the console. This is useful for debugging and understanding what SQLAlchemy is doing for you behind the scenes.

# %%
engine = create_engine('sqlite+pysqlite:///mydatabase.db', echo=True)

# %% [markdown]
# ## Connect to the Database using DataGrip
#
# - Connect to the SQLite database using DataGrip (or any other similar software) to verify that the database file `mydatabase.db` has been created.
# - In DataGrip, create a new data source and select SQLite. Then, select the `mydatabase.db` file to connect to the database.
# - `mydatabase.db` should have been created in the current working directory when you executed the `create_engine()` function.

# %% [markdown]
# ![img.png](assets/images/1_DataGripTOSQLLite.png)

# %% [markdown]
# ## Connect to the Database using the engine in Python

# %%
conn = engine.connect()

# %% [markdown]
# ## Execute Raw SQL Statements using SQLAlchemy Core
#
# - We can also execute raw SQL statements using the connection object.
# - Each SQL statement should be wrapped in the `text()` function available in SQLAlchemy.
# - The `commit()` method then commits any changes to the database.

# %%
conn.execute(text('CREATE TABLE IF NOT EXISTS supplier (name VARCHAR(255), rating int)'))

conn.commit()
# Out:
# 2025-12-09 10:14:36,072 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:14:36,073 INFO sqlalchemy.engine.Engine CREATE TABLE IF NOT EXISTS supplier (name VARCHAR(255), rating int)
# 2025-12-09 10:14:36,073 INFO sqlalchemy.engine.Engine [generated in 0.00133s] ()
# 2025-12-09 10:14:36,081 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# - Confirm that the `supplier` table has been created in the `mydatabase.db` database using DataGrip or any other similar software.

# %% [markdown]
# ![img.png](assets/images/2_CreateTableConfirmation.png)

# %%
conn.execute(text('INSERT INTO supplier (name, rating) VALUES ("Ruiru II Farm", 3);'))

conn.commit()
# Out:
# 2025-12-09 10:15:37,191 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:15:37,193 INFO sqlalchemy.engine.Engine INSERT INTO supplier (name, rating) VALUES ("Ruiru II Farm", 3);
# 2025-12-09 10:15:37,195 INFO sqlalchemy.engine.Engine [generated in 0.00379s] ()
# 2025-12-09 10:15:37,199 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# - Confirm that the new record has been inserted.

# %% [markdown]
# ![img.png](assets/images/3_Insert_Confirmation.png)

# %% [markdown]
# - It is recommended to limit the use of the connection object to a specific context. This can be done using a `with` statement, for example:

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM supplier"))
    print(result.all())
# Out:
# 2025-12-09 10:16:33,226 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:16:33,229 INFO sqlalchemy.engine.Engine SELECT * FROM supplier
# 2025-12-09 10:16:33,231 INFO sqlalchemy.engine.Engine [cached since 8.068s ago] ()
# [('Ruiru II Farm', 3)]
# 2025-12-09 10:16:33,235 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### Create
# - Textual SQL is not the usual way we work with SQLAlchemy. However, when using textual SQL, a Python literal value, even non-strings like integers or dates, **should NEVER be 'stringified' directly into an SQL string**; a parameter should always be used. This avoids SQL injection attacks.

# %%
with engine.connect() as conn:
    conn.execute(
        text("INSERT INTO supplier (name, rating) VALUES (:name, :rating)"),
        [{"name": "Narok 41 Ranch", "rating": 4.8}, {"name": "Ngong Green House", "rating": 2}],
    )
    conn.commit()
# Out:
# 2025-12-09 10:17:09,528 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:17:09,529 INFO sqlalchemy.engine.Engine INSERT INTO supplier (name, rating) VALUES (?, ?)
# 2025-12-09 10:17:09,529 INFO sqlalchemy.engine.Engine [generated in 0.00199s] [('Narok 41 Ranch', 4.8), ('Ngong Green House', 2)]
# 2025-12-09 10:17:09,531 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# - The `BEGIN (implicit)` in the SQLAlchemy Core console means that SQLAlchemy has automatically started a new database transaction for you, without you explicitly calling `begin()`.
#
# - This usually happens when you execute a statement that modifies the database (like `INSERT`, `UPDATE`, or `DELETE`) and no transaction is currently active. The transaction will remain open until you explicitly call `commit()` or `rollback()`.
#
# - Alternatively, we can use the `begin()` method to handle transactions.
#
#   - `engine.begin()` creates a connection and starts a transaction automatically. The transaction is committed if no exceptions occur, or rolled back if an exception is raised. This is useful for ensuring atomic operations and cleaner transaction management.
#   - `engine.connect()` creates a database connection that you can use to execute SQL statements. You must manually manage transactions (i.e., call `commit()` or `rollback()` as needed).
#
# - Using `engine.begin()` is generally preferred for transaction management, as it reduces the risk of leaving transactions open unintentionally. However, if you need more control over the connection and transaction lifecycle, you can choose to use `engine.connect()`. This gives you access to the rollback() method if needed.

# %% [markdown]
# - Analogy: Driving a car with an automatic transmission (using `begin()`) vs. a manual transmission (using `connect()`).
#
# ![img.png](assets/images/4_Automatic-vs-Manual-Transmission.png)

# %%
with engine.begin() as conn:
    conn.execute(
        text("INSERT INTO supplier (name, rating) VALUES (:name, :rating)"),
        [{"name": "Makueni Fruits", "rating": 4}, {"name": "Pwani Farm", "rating": 1.8}],
    )
    conn.commit()
# Out:
# 2025-12-09 10:20:50,192 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:20:50,194 INFO sqlalchemy.engine.Engine INSERT INTO supplier (name, rating) VALUES (?, ?)
# 2025-12-09 10:20:50,194 INFO sqlalchemy.engine.Engine [cached since 220.7s ago] [('Makueni Fruits', 4), ('Pwani Farm', 1.8)]
# 2025-12-09 10:20:50,197 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Read

# %% [markdown]
# **Option 1:** Default print output

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT name, rating FROM supplier"))
    for row in result.fetchall():
        print(row)
    conn.commit()
# Out:
# 2025-12-09 10:21:07,349 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:21:07,352 INFO sqlalchemy.engine.Engine SELECT name, rating FROM supplier
# 2025-12-09 10:21:07,353 INFO sqlalchemy.engine.Engine [generated in 0.00419s] ()
# ('Ruiru II Farm', 3)
# ('Narok 41 Ranch', 4.8)
# ('Ngong Green House', 2)
# ('Makueni Fruits', 4)
# ('Pwani Farm', 1.8)
# 2025-12-09 10:21:07,359 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# **Option 2:** Customized print output

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT name, rating FROM supplier"))
    for row in result.fetchall():
        print(f"name: {row.name},  rating: {row.rating}")
    conn.commit()
# Out:
# 2025-12-09 10:22:11,710 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:22:11,711 INFO sqlalchemy.engine.Engine SELECT name, rating FROM supplier
# 2025-12-09 10:22:11,712 INFO sqlalchemy.engine.Engine [cached since 64.36s ago] ()
# name: Ruiru II Farm,  rating: 3
# name: Narok 41 Ranch,  rating: 4.8
# name: Ngong Green House,  rating: 2
# name: Makueni Fruits,  rating: 4
# name: Pwani Farm,  rating: 1.8
# 2025-12-09 10:22:11,714 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# **Option 3:** Print output and saved as a data frame

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.3.5-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aomondi\documents\github\teaching\objectrelationalmapping\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aomondi\documents\github\teaching\objectrelationalmapping\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\aomondi\documents\github\teaching\objectrelationalmapping\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
# Using cached numpy-2.3.5-cp313-cp313-win_amd64.whl (12.8 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Installing collected packages: pytz, numpy, pandas
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed numpy-2.3.5 pandas-2.3.3 pytz-2025.2

# %%
import pandas as pd

with engine.connect() as conn:
    result = conn.execute(text("SELECT name, rating FROM supplier"))
    df = pd.DataFrame(result.fetchall(), columns=result.keys())
    conn.commit()

display(df)
# Out:
# 2025-12-09 10:26:26,589 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:26:26,591 INFO sqlalchemy.engine.Engine SELECT name, rating FROM supplier
# 2025-12-09 10:26:26,592 INFO sqlalchemy.engine.Engine [cached since 319.2s ago] ()
# 2025-12-09 10:26:26,596 INFO sqlalchemy.engine.Engine COMMIT
#                 name  rating
# 0      Ruiru II Farm     3.0
# 1     Narok 41 Ranch     4.8
# 2  Ngong Green House     2.0
# 3     Makueni Fruits     4.0
# 4         Pwani Farm     1.8

# %% [markdown]
# ### Update

# %%
with engine.connect() as conn:
    conn.execute(
        text("UPDATE supplier SET rating = :rating WHERE name = :name"),
        {"name": "Makueni Fruits", "rating": 5}
    )
    conn.commit()
# Out:
# 2025-12-09 10:27:23,986 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:27:23,987 INFO sqlalchemy.engine.Engine UPDATE supplier SET rating = ? WHERE name = ?
# 2025-12-09 10:27:23,988 INFO sqlalchemy.engine.Engine [generated in 0.00212s] (5, 'Makueni Fruits')
# 2025-12-09 10:27:23,990 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# With multiple statements in one database transaction.

# %%
with engine.connect() as conn:
    conn.execute(
        text("UPDATE supplier SET rating = :rating WHERE name = :name"),
        {"name": "Makueni Fruits", "rating": 4.5}
    )
    conn.execute(
        text("UPDATE supplier SET rating = :rating WHERE name = :name"),
        {"name": "Narok 41 Ranch", "rating": 4.9}
    )
    result = conn.execute(
        text("SELECT name, rating FROM supplier WHERE name = :name"),
        {"name": "Makueni Fruits"}
    )
    for row in result.fetchall():
        print(row)
    conn.commit()
# Out:
# 2025-12-09 10:28:01,233 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:28:01,235 INFO sqlalchemy.engine.Engine UPDATE supplier SET rating = ? WHERE name = ?
# 2025-12-09 10:28:01,236 INFO sqlalchemy.engine.Engine [cached since 37.25s ago] (4.5, 'Makueni Fruits')
# 2025-12-09 10:28:01,241 INFO sqlalchemy.engine.Engine UPDATE supplier SET rating = ? WHERE name = ?
# 2025-12-09 10:28:01,242 INFO sqlalchemy.engine.Engine [cached since 37.26s ago] (4.9, 'Narok 41 Ranch')
# 2025-12-09 10:28:01,243 INFO sqlalchemy.engine.Engine SELECT name, rating FROM supplier WHERE name = ?
# 2025-12-09 10:28:01,244 INFO sqlalchemy.engine.Engine [generated in 0.00088s] ('Makueni Fruits',)
# ('Makueni Fruits', 4.5)
# 2025-12-09 10:28:01,246 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Delete

# %%
with engine.connect() as conn:
    conn.execute(
        text("DELETE FROM supplier WHERE name = :name"),
        {"name": "Pwani Farm"}
    )

    conn.commit()
# Out:
# 2025-12-09 10:29:09,530 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:29:09,531 INFO sqlalchemy.engine.Engine DELETE FROM supplier WHERE name = ?
# 2025-12-09 10:29:09,532 INFO sqlalchemy.engine.Engine [generated in 0.00167s] ('Pwani Farm',)
# 2025-12-09 10:29:09,534 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Rollback to a Savepoint
# - A savepoint allows you to set a point within a transaction that you can roll back to without affecting the entire transaction. This is useful when you want to undo certain operations while keeping others intact.

# %%
with engine.connect() as conn:
    trans = conn.begin()  # start transaction
    try:
        conn.execute(
            text("UPDATE supplier SET rating = :rating WHERE name = :name"),
            {"name": "Makueni Fruits", "rating": 4.3}
        )
        # Create a savepoint
        savepoint_1 = conn.begin_nested()
        conn.execute(
            text("UPDATE supplier SET rating = :rating WHERE name = :name"),
            {"name": "Narok 41 Ranch", "rating": 1.2}
        )
        # Rollback to savepoint (undo last update only)
        savepoint_1.rollback()
        result = conn.execute(
            text("SELECT name, rating FROM supplier WHERE name = :name"),
            {"name": "Makueni Fruits"}
        )
        for row in result.fetchall():
            print(row)
        trans.commit()
    except sqlalchemy.exc.SQLAlchemyError:
        trans.rollback()
        print("Transaction rolled back")
# Out:
# 2025-12-09 10:31:23,363 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:31:23,364 INFO sqlalchemy.engine.Engine UPDATE supplier SET rating = ? WHERE name = ?
# 2025-12-09 10:31:23,364 INFO sqlalchemy.engine.Engine [cached since 239.4s ago] (4.3, 'Makueni Fruits')
# 2025-12-09 10:31:23,367 INFO sqlalchemy.engine.Engine SAVEPOINT sa_savepoint_1
# 2025-12-09 10:31:23,368 INFO sqlalchemy.engine.Engine [no key 0.00081s] ()
# 2025-12-09 10:31:23,369 INFO sqlalchemy.engine.Engine UPDATE supplier SET rating = ? WHERE name = ?
# 2025-12-09 10:31:23,370 INFO sqlalchemy.engine.Engine [cached since 239.4s ago] (1.2, 'Narok 41 Ranch')
# 2025-12-09 10:31:23,371 INFO sqlalchemy.engine.Engine ROLLBACK TO SAVEPOINT sa_savepoint_1
# 2025-12-09 10:31:23,372 INFO sqlalchemy.engine.Engine [no key 0.00073s] ()
# 2025-12-09 10:31:23,373 INFO sqlalchemy.engine.Engine SELECT name, rating FROM supplier WHERE name = ?
# 2025-12-09 10:31:23,374 INFO sqlalchemy.engine.Engine [cached since 202.1s ago] ('Makueni Fruits',)
# ('Makueni Fruits', 4.3)
# 2025-12-09 10:31:23,375 INFO sqlalchemy.engine.Engine COMMIT

# %%
with engine.connect() as conn:
    trans = conn.begin()
    try:
        conn.execute(
            text("UPDATE supplier SET rating = :rating WHERE name = :name"),
            {"name": "Narok 41 Ranch", "rating": 0.5}
        )

        sp1 = conn.begin_nested()  # Savepoint 1
        conn.execute(
            text("UPDATE supplier SET rating = :rating WHERE name = :name"),
            {"name": "Ngong Green House", "rating": 0.9}
        )

        sp2 = conn.begin_nested()  # Savepoint 2
        conn.execute(
            text("UPDATE supplier SET rating = :rating WHERE name = :name"),
            {"name": "Narok 41 Ranch", "rating": 5.0}
        )
        sp2.rollback()  # Undo the last update only
        sp1.rollback()  # Undo up to Savepoint 1 (including changes after sp1)
        trans.commit()
    except sqlalchemy.exc.SQLAlchemyError:
        trans.rollback()
# Out:
# 2025-12-09 10:33:17,019 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-09 10:33:17,021 INFO sqlalchemy.engine.Engine UPDATE supplier SET rating = ? WHERE name = ?
# 2025-12-09 10:33:17,022 INFO sqlalchemy.engine.Engine [cached since 353s ago] (0.5, 'Narok 41 Ranch')
# 2025-12-09 10:33:17,024 INFO sqlalchemy.engine.Engine SAVEPOINT sa_savepoint_1
# 2025-12-09 10:33:17,025 INFO sqlalchemy.engine.Engine [no key 0.00104s] ()
# 2025-12-09 10:33:17,026 INFO sqlalchemy.engine.Engine UPDATE supplier SET rating = ? WHERE name = ?
# 2025-12-09 10:33:17,027 INFO sqlalchemy.engine.Engine [cached since 353s ago] (0.9, 'Ngong Green House')
# 2025-12-09 10:33:17,028 INFO sqlalchemy.engine.Engine SAVEPOINT sa_savepoint_2
# 2025-12-09 10:33:17,029 INFO sqlalchemy.engine.Engine [no key 0.00083s] ()
# 2025-12-09 10:33:17,030 INFO sqlalchemy.engine.Engine UPDATE supplier SET rating = ? WHERE name = ?
# 2025-12-09 10:33:17,031 INFO sqlalchemy.engine.Engine [cached since 353s ago] (5.0, 'Narok 41 Ranch')
# 2025-12-09 10:33:17,033 INFO sqlalchemy.engine.Engine ROLLBACK TO SAVEPOINT sa_savepoint_2
# 2025-12-09 10:33:17,034 INFO sqlalchemy.engine.Engine [no key 0.00087s] ()
# 2025-12-09 10:33:17,035 INFO sqlalchemy.engine.Engine ROLLBACK TO SAVEPOINT sa_savepoint_1
# 2025-12-09 10:33:17,035 INFO sqlalchemy.engine.Engine [no key 0.00080s] ()
# 2025-12-09 10:33:17,036 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Close the Connection
# - It is good practice to close the connection when you are done. This also commits anything that has not yet been committed up to this point.

# %%
conn.close()

# %% [markdown]
# ## References
# SQLAlchemy Project. (2025, December 5). _SQLAlchemy 2.0 Documentation._ SQLAlchemy. https://docs.sqlalchemy.org/en/20/
